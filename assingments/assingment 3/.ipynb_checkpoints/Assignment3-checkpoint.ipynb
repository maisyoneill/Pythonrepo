# %% [markdown]
# Assignment 3

# %% [markdown]
# Statement of use of AI:
# In Task 0, I used it for some guidance in setting up Ollama.

# %% [markdown]
# Task 0

# %%
# Part a 

# Set up ollama using commander prompt and the following is connecting to it using Ollama's API
import requests
import json

url = "http://localhost:11434/api/chat"

data = {
    "model": "gemma3:270m",
    "messages": [
        {
            "role": "user",
            "content": "Hello!"
        }
    ],
    "stream": False 
}

response = requests.post(url, json=data)

print(response.json()["message"]["content"])
# Out:
# Hello! How can I help you today?

# %%
# Part b
# In command prompt I loaded the 270m parameter verison.
url = "http://localhost:11434/api/chat"

data = {
    "model": "gemma3:270m",
    "messages": [
        {
            "role": "user",
            "content": "How many countires do pigeons live in?"
        }
    ],
    "stream": False 
}

response = requests.post(url, json=data)

print(response.json()["message"]["content"])
# Out:
# Pigeons live in a variety of populations, but they are most commonly found in the **Mediterranean region** and the **Middle East**.

# %%
# Part C
url = "http://localhost:11434/api/chat"

data = {
    "model": "gemma3:1b",
    "messages": [
        {
            "role": "user",
            "content": "Can penguins fly?"
        }
    ],
    "stream": False 
}

response = requests.post(url, json=data)

print(response.json()["message"]["content"])
# Out:
# No, penguins cannot fly. Despite their waddling gait and quirky appearance, they are flightless birds!
#
# They’ve evolved to thrive in cold, icy environments, and their wings have evolved into flippers, which are incredibly efficient for swimming and maneuvering in the water.
#
# Here’s a breakdown of why they can’t fly:
#
# * **Wing Structure:** Their wings are shaped like their flippers, perfect for swimming and diving, not for soaring or flapping.
# * **Bone Structure:** Their bones are lightweight and streamlined, crucial for movement in water.
# * **Muscle Structure:** Their leg muscles are adapted for powerful propulsion underwater, not for generating lift.
#
# **Do they glide?** Yes, some penguin species, like the Gentoo penguin, can glide for short distances, using their wings to push themselves through the water. But it’s not true flying.
#
# Do you have any other questions about penguins that you'd like me to answer?
